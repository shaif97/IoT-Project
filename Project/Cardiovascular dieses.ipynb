# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as splt
import seaborn

# %% [markdown]
# # imported librabry

# %%
df=pd.read_csv('cardio_train.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# # Load dataset and checked

# %%
df.shape
# Out:
# (70000, 13)

# %% [markdown]
# # Checked shape of dataset

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# # Check 1st and last 5  column.

# %%
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %% [markdown]
# # Visualization cardio

# %%
seaborn.countplot(df['cardio'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %% [markdown]
# # Visualization smoke

# %%
seaborn.countplot(df['smoke'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoke', ylabel='count'>

# %% [markdown]
# # Visualization alhcohol

# %%
seaborn.countplot(df['alco'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alco', ylabel='count'>

# %% [markdown]
# # Check null value (t or f)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().any()
# Out:
# id             False
# age            False
# gender         False
# height         False
# weight         False
# ap_hi          False
# ap_lo          False
# cholesterol    False
# gluc           False
# smoke          False
# alco           False
# active         False
# cardio         False
# dtype: bool

# %% [markdown]
# # Check null value (0 or 1)

# %%
df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# # Check color blind

# %%
seaborn.countplot(x='gender',hue='cardio',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # Convert age day to year

# %%
df['yr']=(df['age']/365)

# %%
df['yr']
# Out:
# 0        50.391781
# 1        55.419178
# 2        51.663014
# 3        48.282192
# 4        47.873973
#            ...
# 69995    52.712329
# 69996    61.920548
# 69997    52.235616
# 69998    61.454795
# 69999    56.273973
# Name: yr, Length: 70000, dtype: float64

# %% [markdown]
# # Make year round

# %%
df['yr']=(df['age']/365).round(0)

# %%
df['yr']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr, Length: 70000, dtype: float64

# %% [markdown]
# # Visualise as year.

# %%
seaborn.countplot(x='yr',hue='cardio',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))
# Out:
# <AxesSubplot:xlabel='yr', ylabel='count'>

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio    yr
# ...

# %%
df.shape
# Out:
# (70000, 14)

# %% [markdown]
# # Describe data

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# # Describe cardio

# %%
df['cardio'].describe()
# Out:
# count    70000.000000
# mean         0.499700
# std          0.500003
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: cardio, dtype: float64

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
df=df.drop(['yr'],axis=1)

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df=df.drop(['id'],axis=1)

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 12)

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y=df.iloc[:,:12]

# %%
y
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
y=df.iloc[:,11]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Take data for test and train

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.3, random_state=1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 23561  16136       2     169    71.0    100     80            1     1      1
# 34858  14615       1     158    69.0    140     80            2     1      0
# 54953  20507       1     164    65.0    120     80            1     1      0
# 59230  16720       1     153    53.0    100     60            1     1      0
# 1730   21050       1     159    71.0    140     90            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 49100  21289       2     175    78.0    120     80            1     1      0
# 20609  19116       1     164    68.0    120     80            1     1      0
# 21440  18049       2     178    82.0    120     80            1     1      0
# 50057  21957       1     169    77.0    120     80            1     1      0
# 5192   20671       1     174    65.0    160     90            2     2      0
#
#        alco  active
# 23561     0       1
# ...

# %%
xtest
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 10840  15216       1     165    61.0    120     80            1     1      0
# 56267  19815       1     164    54.0    110     80            1     1      0
# 14849  20563       1     170    69.0    120     80            1     1      0
# 62726  16625       1     167    57.0    110     70            1     1      0
# 47180  14451       1     158   110.0    120     80            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 66702  18043       1     159    54.0    100     60            1     1      0
# 12435  22077       1     137   161.0    150    100            2     1      0
# 55373  22702       2     161    53.0    140    100            1     1      0
# 1362   20999       2     169    62.0    130     80            2     1      1
# 66135  15104       1     165    59.0    120     80            1     1      0
#
#        alco  active
# 10840     0       1
# ...

# %%
ytrain
# Out:
# 54968    1
# 6029     1
# 38355    0
# 37430    1
# 62603    0
#         ..
# 21243    1
# 45891    1
# 42613    0
# 43567    0
# 68268    1
# Name: cardio, Length: 35000, dtype: int64

# %%
ytest
# Out:
# 10840    0
# 56267    0
# 14849    0
# 62726    0
# 47180    0
#         ..
# 66702    0
# 12435    1
# 55373    1
# 1362     0
# 66135    0
# Name: cardio, Length: 35000, dtype: int64

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain,ytrain)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
cm = confusion_matrix(ytest, y_pred)
accuracy = accuracy_score(ytest, y_pred)
precision = precision_score(ytest, y_pred)
recall = recall_score(ytest, y_pred)
f1 = f1_score(ytest, y_pred)

# %%
Rclf=LogisticRegression()

# %%
Rclf.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
Rclf.score(xtrain,ytrain)
# Out:
# 0.6956285714285714

# %% [markdown]
# # RandomForest

# %% [markdown]
# # Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rclf=RandomForestClassifier()

# %%
Rclf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
Rclf.score(xtrain,ytrain)
# Out:
# 0.9998571428571429

# %%
Rclf.score(xtest,ytest)
# Out:
# 0.7166

# %% [markdown]
# # DecisionTree apply

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Clf=DecisionTreeClassifier()

# %%
Clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
Clf.score(xtrain,ytrain)
# Out:
# 0.9998857142857143

# %%
Clf.score(xtest,ytest)
# Out:
# 0.6354285714285715

# %% [markdown]
# # KNN apply

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
knn_classifier=KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(xtrain,ytrain)
score=cross_val_score(knn_classifier,xtrain,ytrain,cv=10)
y_pred_knn=knn_classifier.predict(xtest)
accuracy_score(ytest,y_pred_knn)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
